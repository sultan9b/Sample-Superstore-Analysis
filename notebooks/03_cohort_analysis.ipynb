# %% [markdown]
# ## **Cohort Analysis (Когортный анализ)**
# *Когортный анализ* - один из методов исследования потребителей.  <br>
# **Цель:** определить как ведут себя клиенты в группах по одинаковым характеристикам или атрибутам и отслеживание их поведения во времени.

# %%
# Импорт нужных библиотек
import pandas as pd
import os
from clickhouse_driver import Client
import clickhouse_connect
import streamlit as st

# %%
# Подключение к базе данных ClickHouse и загрузка данных в DataFrame

# Данные для подключения к ClickHouse
ch_host = 'localhost'
ch_port = '8123'
ch_user = os.getenv('CLICKHOUSE_USER')
ch_password = os.getenv('CLICKHOUSE_PASSWORD')
ch_database = 'dwh'

# Создание соединение с ClickHouse
ch_connect = clickhouse_connect.get_client(
    host=ch_host,
    port=ch_port,
    username=ch_user,
    password=ch_password,
    database=ch_database
)

# %%
# Загрузка и чтение данных с clickhouse
df = ch_connect.query_df('SELECT * FROM dwh.sales_fact')
print('ТАБЛИЦА ПО ПРОДАЖАМ ЗАГРУЖЕНА УСПЕШНО!')
print(f'- Количество строк в таблице: {len(df)}', f'- Количество столбцов в таблице: {len(df.columns)}', sep='\n', end='\n\n')
df.head(10)
# Out:
# ТАБЛИЦА ПО ПРОДАЖАМ ЗАГРУЖЕНА УСПЕШНО!
# - Количество строк в таблице: 9994
# - Количество столбцов в таблице: 18
#          order_id  row_id order_date  customer_name      segment  \
# 0  CA-2018-103800    7981 2018-01-03  Darren Powers     Consumer
# 1  CA-2018-112326     740 2018-01-04  Phillina Ober  Home Office
# 2  CA-2018-112326     741 2018-01-04  Phillina Ober  Home Office
# 3  CA-2018-112326     742 2018-01-04  Phillina Ober  Home Office
# 4  CA-2018-141817    1760 2018-01-05     Mick Brown     Consumer
# 5  CA-2018-167199    7475 2018-01-06  Maria Etezadi  Home Office
# 6  CA-2018-167199    7481 2018-01-06  Maria Etezadi  Home Office
# 7  CA-2018-167199    7476 2018-01-06  Maria Etezadi  Home Office
# 8  CA-2018-167199    7477 2018-01-06  Maria Etezadi  Home Office
# 9  CA-2018-106054    7181 2018-01-06  Jack O'Briant    Corporate
#
#            city         state   region  \
# 0       Houston         Texas  Central
# 1    Naperville      Illinois  Central
# 2    Naperville      Illinois  Central
# 3    Naperville      Illinois  Central
# 4  Philadelphia  Pennsylvania     East
# 5     Henderson      Kentucky    South
# 6     Henderson      Kentucky    South
# 7     Henderson      Kentucky    South
# 8     Henderson      Kentucky    South
# 9        Athens       Georgia    South
#
#                                         product_name         category  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Office Supplies
# 1                                          Avery 508  Office Supplies
# 2                      SAFCO Boltless Steel Shelving  Office Supplies
# 3         GBC Standard Plastic Binding Systems Combs  Office Supplies
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...  Office Supplies
# 5            Global Deluxe High-Back Manager's Chair        Furniture
# 6    Southworth 25% Cotton Granite Paper & Envelopes  Office Supplies
# 7                Ibico Hi-Tech Manual Binding System  Office Supplies
# 8            Rogers Handheld Barrel Pencil Sharpener  Office Supplies
# 9  Dixon Prang Watercolor Pencils, 10-Color Set w...  Office Supplies
#
#   sub_category       ship_mode      ship_status  profit  quantity  discount  \
# 0        Paper  Standard Class    Shipped Early       6         2       0.2
# 1       Labels  Standard Class    Shipped Early       4         3       0.2
# 2      Storage  Standard Class    Shipped Early      65         3       0.2
# 3      Binders  Standard Class    Shipped Early       5         2       0.8
# 4          Art  Standard Class     Shipped Late       5         3       0.2
# 5       Chairs  Standard Class    Shipped Early     746         9       0.0
# 6        Paper  Standard Class    Shipped Early       3         1       0.0
# 7      Binders  Standard Class    Shipped Early     274         2       0.0
# 8          Art  Standard Class    Shipped Early       1         2       0.0
# 9          Art     First Class  Shipped On Time       5         3       0.0
#
#    sales  sales_forecast
# 0     16              25
# 1     12              18
# 2    273             408
# 3      4               5
# 4     20              29
# 5   2574            3855
# 6      7              10
# 7    610             914
# 8      5               8
# 9     13              19

# %%
# Вывод информации о клиентах и их заказах
print(f'| {"ТАБЛИЦА ПО ПРОДАЖАМ":<27}', '|')
print( '-' * 31)
print(f'| {"Количество заказов":<20} | {len(df.order_id.unique()):<3} |')
print(f'| {"Количество клиентов":<20} | {len(df.customer_name.unique()):<4} |')
print(f'| {"Количество сегментов":<15} | {len(df.segment.unique()):<4} |')
# Out:
# | ТАБЛИЦА ПО ПРОДАЖАМ         |
# -------------------------------
# | Количество заказов   | 5009 |
# | Количество клиентов  | 793  |
# | Количество сегментов | 3    |
